# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('/content/drive/MyDrive/item_data.csv')
df.shape
# Out:
# (87398, 4)

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df = df.drop_duplicates().reset_index().drop(['index'], axis = 1)

# %%
sns.barplot(x = df['rates'].value_counts().index, y = df['rates'].value_counts())

df['label'] = df['rates'].apply(lambda x : (1 if x >= 4 else 0))

# %%
df['label'].value_counts()
# Out:
# 1    64407
# 0    10125
# Name: label, dtype: int64

# %%
from hanspell import spell_checker
result = spell_checker.check(u'너네 집에 가도 되?')

for key, value in result.words.items():
    print(key, value)
    
# 0 : 문제 없음, 1 : 맞춤법 틀림, 2 : 띄어쓰기 틀림, 3 : 표준어 아님, 4 : 통계적 교정
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-01a6432bb2e2> in <module>()
# ----> 1 from hanspell import spell_checker
#       2 result = spell_checker.check(u'너네 집에 가도 되?')
#       3
#       4 for key, value in result.words.items():
#       5     print(key, value)
#
# ModuleNotFoundError: No module named 'hanspell'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
